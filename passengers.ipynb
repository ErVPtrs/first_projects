# %%
# !pwd
# Out:
# /Users/ervandpetrosyan/Learn_studi/home_work

# %%
import pandas as pd
df = pd.read_csv('~/Downloads/air-passengers-per-fatality.csv')

# %%
df.shape
# Out:
# (47, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 4 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Entity                                 47 non-null     object
#  1   Code                                   47 non-null     object
#  2   Year                                   47 non-null     int64
#  3   Million passengers per fatality (ASN)  47 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.6+ KB
